# %%
import pandas as pd 
from pathlib import Path
import os

# %%
list(Path.cwd().iterdir())
# Out:
# [WindowsPath('c:/Users/david/OneDrive/Área de Trabalho/FranFoods/Dados/Fatos/fato Metas/metas_vendedores_2021_2025.xlsx')]

# %%
arquivo=Path.cwd()/"metas_vendedores_2021_2025.xlsx"

# %%
df=pd.read_excel(arquivo)

# %%
df['Meta_Valor']=df['Meta_Valor']*0.33

# %%
df.to_excel(arquivo,index=False)

# %%
a[,"Valor_Bruto"].sum()
# Out:
# np.float64(415256834.5)

# %%
os.chdir(Path.cwd().parent)

# %%
list(Path.cwd().iterdir())
# Out:
# [WindowsPath('c:/Users/david/OneDrive/Área de Trabalho/FranFoods/Dados/Fatos/Fato Vendas/vendas_industria_2021_2025 (1).xlsx')]

# %%
os.chdir(Path.cwd()/"Fato Vendas")

# %%
arquivo=Path.cwd()/'vendas_industria_2021_2025 (1).xlsx'

# %%
a=pd.read_excel(arquivo)

# %%
a['Valor_Bruto']=a['Valor_Bruto']*1.3

# %%
a.to_excel(arquivo,index=False)
